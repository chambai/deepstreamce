# %%
import util
import app

util.paramDefFile = util.getFullFileName("setup/paramdef.txt")
setupFile = 'setup/2classes01_ce6_500_test_r0-04_k80.txt'
util.setupFile = util.getFullFileName(setupFile)

app = app.App()
app.loadDnnModel()
app.getActivations()
app.reduceActivations()
app.setupActivationAnalysis()
app.processDataStream()
# Out:
# Using TensorFlow backend.
# /home/jupyter/deepactistream/deepstreamce/setup
# Successfully created the directory output/2classes01_ce6_500_test_r0-04_k80--200301_165854
# 2020-03-01 16:58:54.807982 Setup file:  /home/jupyter/deepactistream/deepstreamce/setup/2classes01_ce6_500_test_r0-04_k80.txt
# 2020-03-01 16:58:54.808262 ----------------- start of setup parameters ----------------------
# 2020-03-01 16:58:54.808558 # Simple 18 layer DNN Model trained on 5 classes of the cifar 10 dataset.
# 2020-03-01 16:58:54.808771 # Data instances supplied to DNN via time loop
# 2020-03-01 16:58:54.808852 # Final activation layer, Global Max Pooling (GMP) applied
# 2020-03-01 16:58:54.808918 # (uses the subsequent layer to the final activation layer as that provides GMP) 2 classes
# 2020-03-01 16:58:54.809011 # Autoencoder reduction
# 2020-03-01 16:58:54.809151 #
# 2020-03-01 16:58:54.809228 LoggingEnabled=True
# 2020-03-01 16:58:54.809293 LogPath=/home/jupyter/deepactistream/results
# ...
